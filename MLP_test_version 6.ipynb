# %%
import numpy as np
import pandas as pd
import keras
import warnings
warnings.filterwarnings(action='ignore')
import sys

from keras.models import Sequential
from keras.layers import Dense,Dropout
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Data 불러오기

# %%
data = pd.read_csv('data_preprocessing.csv')
data
# Out:
#          year  month CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM  SEX  region_diff  \
# 0        2019      1           강원         강릉시  건강보조식품 소매업    1            1
# 1        2019      1           강원         강릉시  건강보조식품 소매업    1            1
# 2        2019      1           강원         강릉시  건강보조식품 소매업    1            1
# 3        2019      1           강원         강릉시  건강보조식품 소매업    1            1
# 4        2019      1           강원         강릉시  건강보조식품 소매업    1            1
# ...       ...    ...          ...         ...         ...  ...          ...
# 2691680  2020      3           충북         충주시    휴양콘도 운영업    1            1
# 2691681  2020      3           충북         충주시    휴양콘도 운영업    1            1
# 2691682  2020      3           충북         충주시    휴양콘도 운영업    1            1
# 2691683  2020      3           충북         충주시    휴양콘도 운영업    1            1
# 2691684  2020      3           충북         충주시    휴양콘도 운영업    2            1
#
#          AGE  CSTMR_CNT  CNT      AMT
# 0         20          4    4   311200
# 1         30          7    8  1374500
# 2         40          7    8  2764300
# 3         50         21   21  3690830
# 4         60         19   20  1433500
# ...      ...        ...  ...      ...
# 2691680   30          3    4    43300
# 2691681   40          3    3    35000
# 2691682   50          4    6   188000
# 2691683   60          3    3   194000
# 2691684   50          4    6    99000
#
# [2691685 rows x 11 columns]

# %% [markdown]
# ### Train구분

# %%
Train_data = data.loc[(data['year']==2020)&((data['month']==1)|(data['month']==2)|
                                              (data['month']==3))]
Train_data_X = Train_data.drop(['AMT','year','CNT','CSTMR_CNT'],axis=1)
Train_data = Train_data.drop(['CNT','year','CSTMR_CNT'],axis=1)
print('Train_data :',Train_data.shape)
print('Train_data_X :',Train_data_X.shape)
# Out:
# Train_data : (521750, 8)
# Train_data_X : (521750, 7)

# %% [markdown]
# ### SET Pred_Dataframe

# %%
def Pred_data_def(raw_data):
    temp         = []
    SEX          = raw_data['SEX'].unique()
    Region_diff  = raw_data['region_diff'].unique()
    AGE          = raw_data['AGE'].unique()
    month        = [4,7]
    CARD_SIDO_NM = raw_data['CARD_SIDO_NM'].unique()
    STD_CLSS_NM  = raw_data['STD_CLSS_NM'].unique()
    
    for sido in CARD_SIDO_NM:
        df = raw_data[raw_data["CARD_SIDO_NM"] == sido]
        ccg_list = df['CARD_CCG_NM'].unique()
        for ccg in ccg_list:
            for std in STD_CLSS_NM:
                for age in AGE: 
                    for sex in SEX:
                        for region in Region_diff:
                            for i in month:
                                temp.append([i, sido, ccg, std, sex, region, age])

    temp = np.array(temp)
    Pred_data = pd.DataFrame(data= temp, columns= ['month', 'CARD_SIDO_NM', 'CARD_CCG_NM',
                                                   'STD_CLSS_NM', 'SEX', 'region_diff', 'AGE'])
    return Pred_data

# %% [markdown]
# ### Pred_Data

# %%
Pred_data = Pred_data_def(Train_data_X)
print('Pred_data :',Pred_data.shape)
# Out:
# Pred_data : (861000, 7)

# %% [markdown]
# ### Type Change

# %%
Pred_data['month'] = Pred_data['month'].astype('int64')
Pred_data['SEX'] = Pred_data['SEX'].astype('int64')
Pred_data['region_diff'] = Pred_data['region_diff'].astype('int64')
Pred_data['AGE'] = Pred_data['AGE'].astype('int64')

# %% [markdown]
# ### Train_data Encoding

# %%
dtypes = Train_data.dtypes
encoders = {}
for column in Train_data.columns:
    if str(dtypes[column]) == 'object':
        encoder = LabelEncoder()
        encoder.fit(Train_data[column])
        encoders[column] = encoder
        
df_num = Train_data.copy()        
for column in encoders.keys():
    encoder = encoders[column]
    df_num[column] = encoder.transform(Train_data[column])
df_num
# Out:
#          month  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  SEX  region_diff  AGE  \
# 2169935      1             0            3            0    1            1   30
# 2169936      1             0            3            0    1            1   40
# 2169937      1             0            3            0    1            1   50
# 2169938      1             0            3            0    1            1   60
# 2169939      1             0            3            0    1            1   70
# ...        ...           ...          ...          ...  ...          ...  ...
# 2691680      3            16          202           40    1            1   30
# 2691681      3            16          202           40    1            1   40
# 2691682      3            16          202           40    1            1   50
# 2691683      3            16          202           40    1            1   60
# 2691684      3            16          202           40    2            1   50
#
#              AMT
# 2169935  1903450
# 2169936  1845900
# 2169937  6132260
# 2169938  3162700
# 2169939   554000
# ...          ...
# 2691680    43300
# 2691681    35000
# 2691682   188000
# 2691683   194000
# 2691684    99000
#
# [521750 rows x 8 columns]

# %% [markdown]
# ### Pred_data Encoding

# %%
ptypes = Pred_data.dtypes
encoders = {}
for column in Pred_data.columns:
    if str(ptypes[column]) == 'object':
        encoder = LabelEncoder()
        encoder.fit(Pred_data[column])
        encoders[column] = encoder
        
p_num = Pred_data.copy()        
for column in encoders.keys():
    encoder = encoders[column]
    p_num[column] = encoder.transform(Pred_data[column])
p_num
# Out:
#         month  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  SEX  region_diff  AGE
# 0           4             0            3            0    1            1   30
# 1           7             0            3            0    1            1   30
# 2           4             0            3            0    1            2   30
# 3           7             0            3            0    1            2   30
# 4           4             0            3            0    1            3   30
# ...       ...           ...          ...          ...  ...          ...  ...
# 860995      7            16          202           30    2            1   10
# 860996      4            16          202           30    2            2   10
# 860997      7            16          202           30    2            2   10
# 860998      4            16          202           30    2            3   10
# 860999      7            16          202           30    2            3   10
#
# [861000 rows x 7 columns]

# %% [markdown]
# ### Model

# %%
y_train = df_num['AMT'].to_numpy(dtype=np.float32).reshape(-1,1)
X_train = df_num.drop(['AMT'],axis=1).to_numpy(dtype=np.float32)
X_test = p_num.to_numpy(dtype=np.float32)        

num_hidden_units = 150
input_dim = X_train.shape[1]

model = Sequential()
model.add(Dense(num_hidden_units,input_dim = input_dim, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_hidden_units,kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_hidden_units,kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_hidden_units,kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_hidden_units, kernel_initializer='normal',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_hidden_units,kernel_initializer='normal', activation='relu'))
model.add(Dense(1))
model.compile(loss='MeanAbsolutePercentageError', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=555, batch_size=100, verbose=1)
# Out:
# Epoch 1/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.8623 - accuracy: 0.0000e+00
# Epoch 2/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.5668 - accuracy: 0.0000e+00
# Epoch 3/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.4233 - accuracy: 0.0000e+00
# Epoch 4/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.3891 - accuracy: 0.0000e+00
# Epoch 5/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.3178 - accuracy: 0.0000e+00
# Epoch 6/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.2670 - accuracy: 0.0000e+00
# Epoch 7/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.2578 - accuracy: 0.0000e+00
# Epoch 8/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.2063 - accuracy: 0.0000e+00
# Epoch 9/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.1894 - accuracy: 0.0000e+00
# Epoch 10/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.1415 - accuracy: 0.0000e+00
# Epoch 11/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.1112 - accuracy: 0.0000e+00
# Epoch 12/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.0569 - accuracy: 0.0000e+00
# Epoch 13/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.0083 - accuracy: 0.0000e+00
# Epoch 14/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 90.0464 - accuracy: 0.0000e+00
# Epoch 15/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9795 - accuracy: 0.0000e+00
# Epoch 16/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9920 - accuracy: 0.0000e+00
# Epoch 17/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9492 - accuracy: 0.0000e+00
# Epoch 18/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9733 - accuracy: 0.0000e+00
# Epoch 19/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9506 - accuracy: 0.0000e+00
# Epoch 20/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9635 - accuracy: 0.0000e+00
# Epoch 21/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9651 - accuracy: 0.0000e+00
# Epoch 22/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9294 - accuracy: 0.0000e+00
# Epoch 23/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9208 - accuracy: 0.0000e+00
# Epoch 24/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9268 - accuracy: 0.0000e+00
# Epoch 25/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8978 - accuracy: 0.0000e+00
# Epoch 26/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9249 - accuracy: 0.0000e+00
# Epoch 27/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9214 - accuracy: 0.0000e+00
# Epoch 28/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8897 - accuracy: 0.0000e+00
# Epoch 29/555
# 5218/5218 [==============================] - 26s 5ms/step - loss: 89.9011 - accuracy: 0.0000e+00
# Epoch 30/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9179 - accuracy: 0.0000e+00
# Epoch 31/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9067 - accuracy: 0.0000e+00
# Epoch 32/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.9120 - accuracy: 0.0000e+00
# Epoch 33/555
# 5218/5218 [==============================] - 26s 5ms/step - loss: 89.8801 - accuracy: 0.0000e+00
# Epoch 34/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8827 - accuracy: 0.0000e+00
# Epoch 35/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8436 - accuracy: 0.0000e+00
# Epoch 36/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8586 - accuracy: 0.0000e+00
# Epoch 37/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8550 - accuracy: 0.0000e+00
# Epoch 38/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8523 - accuracy: 0.0000e+00
# Epoch 39/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8327 - accuracy: 0.0000e+00
# Epoch 40/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8498 - accuracy: 0.0000e+00
# Epoch 41/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8512 - accuracy: 0.0000e+00
# Epoch 42/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8260 - accuracy: 0.0000e+00
# Epoch 43/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8359 - accuracy: 0.0000e+00
# Epoch 44/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8126 - accuracy: 0.0000e+00
# Epoch 45/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8285 - accuracy: 0.0000e+00
# Epoch 46/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8147 - accuracy: 0.0000e+00
# Epoch 47/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8311 - accuracy: 0.0000e+00
# Epoch 48/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8149 - accuracy: 0.0000e+00
# Epoch 49/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8001 - accuracy: 0.0000e+00
# Epoch 50/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8479 - accuracy: 0.0000e+00
# Epoch 51/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8172 - accuracy: 0.0000e+00
# Epoch 52/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7760 - accuracy: 0.0000e+00
# Epoch 53/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7733 - accuracy: 0.0000e+00
# Epoch 54/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8162 - accuracy: 0.0000e+00
# Epoch 55/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8117 - accuracy: 0.0000e+00
# Epoch 56/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8090 - accuracy: 0.0000e+00
# Epoch 57/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7704 - accuracy: 0.0000e+00
# Epoch 58/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7903 - accuracy: 0.0000e+00
# Epoch 59/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7876 - accuracy: 0.0000e+00
# Epoch 60/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8011 - accuracy: 0.0000e+00
# Epoch 61/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7846 - accuracy: 0.0000e+00
# Epoch 62/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7773 - accuracy: 0.0000e+00
# Epoch 63/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8306 - accuracy: 0.0000e+00
# Epoch 64/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7833 - accuracy: 0.0000e+00
# Epoch 65/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.8109 - accuracy: 0.0000e+00
# Epoch 66/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7611 - accuracy: 0.0000e+00
# Epoch 67/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7598 - accuracy: 0.0000e+00
# Epoch 68/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7691 - accuracy: 0.0000e+00
# Epoch 69/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7675 - accuracy: 0.0000e+00
# Epoch 70/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7655 - accuracy: 0.0000e+00
# Epoch 71/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7498 - accuracy: 0.0000e+00
# Epoch 72/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7397 - accuracy: 0.0000e+00
# Epoch 73/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7911 - accuracy: 0.0000e+00
# Epoch 74/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7525 - accuracy: 0.0000e+00
# Epoch 75/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7733 - accuracy: 0.0000e+00
# Epoch 76/555
# 5218/5218 [==============================] - 23s 4ms/step - loss: 89.7844 - accuracy: 0.0000e+00
# Epoch 77/555
# 5218/5218 [==============================] - 23s 4ms/step - loss: 89.7729 - accuracy: 0.0000e+00
# Epoch 78/555
# 5218/5218 [==============================] - 24s 5ms/step - loss: 89.7269 - accuracy: 0.0000e+00
# Epoch 79/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7146 - accuracy: 0.0000e+00
# Epoch 80/555
# 5218/5218 [==============================] - 24s 5ms/step - loss: 89.7661 - accuracy: 0.0000e+00
# Epoch 81/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7578 - accuracy: 0.0000e+00
# Epoch 82/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7407 - accuracy: 0.0000e+00
# Epoch 83/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7790 - accuracy: 0.0000e+00
# Epoch 84/555
# 5218/5218 [==============================] - 24s 5ms/step - loss: 89.7762 - accuracy: 0.0000e+00
# Epoch 85/555
# 5218/5218 [==============================] - 24s 5ms/step - loss: 89.7932 - accuracy: 0.0000e+00
# Epoch 86/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7838 - accuracy: 0.0000e+00
# Epoch 87/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7553 - accuracy: 0.0000e+00
# Epoch 88/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7703 - accuracy: 0.0000e+00
# Epoch 89/555
# 5218/5218 [==============================] - 24s 5ms/step - loss: 89.7628 - accuracy: 0.0000e+00
# Epoch 90/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7607 - accuracy: 0.0000e+00
# Epoch 91/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7362 - accuracy: 0.0000e+00
# Epoch 92/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7204 - accuracy: 0.0000e+00
# Epoch 93/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7290 - accuracy: 0.0000e+00
# Epoch 94/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7239 - accuracy: 0.0000e+00
# Epoch 95/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6997 - accuracy: 0.0000e+00
# Epoch 96/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7234 - accuracy: 0.0000e+00
# Epoch 97/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7391 - accuracy: 0.0000e+00
# Epoch 98/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6891 - accuracy: 0.0000e+00
# Epoch 99/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7046 - accuracy: 0.0000e+00
# Epoch 100/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6999 - accuracy: 0.0000e+00
# Epoch 101/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7054 - accuracy: 0.0000e+00
# Epoch 102/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7004 - accuracy: 0.0000e+00
# Epoch 103/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6914 - accuracy: 0.0000e+00
# Epoch 104/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6875 - accuracy: 0.0000e+00
# Epoch 105/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7162 - accuracy: 0.0000e+00
# Epoch 106/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7482 - accuracy: 0.0000e+00
# Epoch 107/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6608 - accuracy: 0.0000e+00
# Epoch 108/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6964 - accuracy: 0.0000e+00
# Epoch 109/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6617 - accuracy: 0.0000e+00
# Epoch 110/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6982 - accuracy: 0.0000e+00
# Epoch 111/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6899 - accuracy: 0.0000e+00
# Epoch 112/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6748 - accuracy: 0.0000e+00
# Epoch 113/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6833 - accuracy: 0.0000e+00
# Epoch 114/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7033 - accuracy: 0.0000e+00
# Epoch 115/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6652 - accuracy: 0.0000e+00
# Epoch 116/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6658 - accuracy: 0.0000e+00
# Epoch 117/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7097 - accuracy: 0.0000e+00
# Epoch 118/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6334 - accuracy: 0.0000e+00
# Epoch 119/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6738 - accuracy: 0.0000e+00
# Epoch 120/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6721 - accuracy: 0.0000e+00
# Epoch 121/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6502 - accuracy: 0.0000e+00
# Epoch 122/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6979 - accuracy: 0.0000e+00
# Epoch 123/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6176 - accuracy: 0.0000e+00
# Epoch 124/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.7248 - accuracy: 0.0000e+00
# Epoch 125/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6678 - accuracy: 0.0000e+00
# Epoch 126/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6681 - accuracy: 0.0000e+00
# Epoch 127/555
# 5218/5218 [==============================] - 24s 5ms/step - loss: 89.6670 - accuracy: 0.0000e+00
# Epoch 128/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6681 - accuracy: 0.0000e+00
# Epoch 129/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6631 - accuracy: 0.0000e+00
# Epoch 130/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6370 - accuracy: 0.0000e+00
# Epoch 131/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6538 - accuracy: 0.0000e+00
# Epoch 132/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6506 - accuracy: 0.0000e+00
# Epoch 133/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6498 - accuracy: 0.0000e+00
# Epoch 134/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6545 - accuracy: 0.0000e+00
# Epoch 135/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6548 - accuracy: 0.0000e+00
# Epoch 136/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6461 - accuracy: 0.0000e+00
# Epoch 137/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6712 - accuracy: 0.0000e+00
# Epoch 138/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6202 - accuracy: 0.0000e+00
# Epoch 139/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6494 - accuracy: 0.0000e+00
# Epoch 140/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6432 - accuracy: 0.0000e+00
# Epoch 141/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6433 - accuracy: 0.0000e+00
# Epoch 142/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6663 - accuracy: 0.0000e+00
# Epoch 143/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6583 - accuracy: 0.0000e+00
# Epoch 144/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6272 - accuracy: 0.0000e+00
# Epoch 145/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6266 - accuracy: 0.0000e+00
# Epoch 146/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6107 - accuracy: 0.0000e+00
# Epoch 147/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6295 - accuracy: 0.0000e+00
# Epoch 148/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6189 - accuracy: 0.0000e+00
# Epoch 149/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.5788 - accuracy: 0.0000e+00
# Epoch 150/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6239 - accuracy: 0.0000e+00
# Epoch 151/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6554 - accuracy: 0.0000e+00
# Epoch 152/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6016 - accuracy: 0.0000e+00
# Epoch 153/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6015 - accuracy: 0.0000e+00
# Epoch 154/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6301 - accuracy: 0.0000e+00
# Epoch 155/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.5691 - accuracy: 0.0000e+00
# Epoch 156/555
# 5218/5218 [==============================] - 26s 5ms/step - loss: 89.6292 - accuracy: 0.0000e+00
# Epoch 157/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6153 - accuracy: 0.0000e+00
# Epoch 158/555
# 5218/5218 [==============================] - 26s 5ms/step - loss: 89.6306 - accuracy: 0.0000e+00
# Epoch 159/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.5731 - accuracy: 0.0000e+00
# Epoch 160/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6006 - accuracy: 0.0000e+00
# Epoch 161/555
# 5218/5218 [==============================] - 26s 5ms/step - loss: 89.6052 - accuracy: 0.0000e+00
# Epoch 162/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6237 - accuracy: 0.0000e+00
# Epoch 163/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6111 - accuracy: 0.0000e+00
# Epoch 164/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.5990 - accuracy: 0.0000e+00
# Epoch 165/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.6189 - accuracy: 0.0000e+00
# Epoch 166/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.5999 - accuracy: 0.0000e+00
# Epoch 167/555
# 5218/5218 [==============================] - 25s 5ms/step - loss: 89.5920 - accuracy: 0.0000e+00
# Epoch 168/555
# 2283/5218 [============>.................] - ETA: 14s - loss: 89.5995 - accuracy: 0.0000e+00

# %% [markdown]
# ### Predict

# %%
pred = model.predict(X_test)
Pred_data['AMT'] = pred
Pred_data['REG_YYMM'] = ('20200' + Pred_data['month'].astype('str')).astype('int64')
Pred_data = Pred_data.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop=False) 
Pred_data.drop(['month','SEX','region_diff','AGE'],axis=1,inplace=True)
Pred_data

# %% [markdown]
# ### Save to csv

# %%
submission = pd.read_csv('submission_mingsu.csv',index_col = 0)
submission = submission.drop(['AMT'], axis=1)
submission = submission.merge(Pred_data, left_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
submission.index.name = 'id'
submission.to_csv('submission_mingsu.csv', encoding='utf-8-sig')
submission.head(10)
